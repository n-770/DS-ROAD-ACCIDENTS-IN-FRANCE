# %%
"""
notebook: 1.0.-leibold-data-preprocessing_aggr.jpynb

author: Christian Leibold

created/updated at: 2025-12-05

intention: create joblib data file including concatenated data from acc, loca, veh, ind 
           having insersections in loca data allready reduced to one line

content:
---------
-> reads in csv files with acc, loca, veh, ind data
-> reducing intersection in locations data to one line (keep road with max max_speed)
-> safe data in joblib file for reuse

"""

# %%
import pandas as pd
import numpy as np
from joblib import dump, load

import seaborn as sns
import matplotlib as plt

import itertools
from scipy.stats import chi2_contingency
import scipy.stats as stats

# %%
#----------------------------------------------------------------------------------------------------------------------------------
# import joblibs from prior step / show first infos about datasets
#----------------------------------------------------------------------------------------------------------------------------------
df_acc = load(r'..\..\data\processed\2_preprocessing\1.1-simmler-data-preprocessing_accidents.joblib')
df_loca = load(r'..\..\data\processed\2_preprocessing\1.1-munz-data-preprocessing_locations.joblib')
df_ind = load(r'..\..\data\processed\2_preprocessing\1.3-becker-data-preprocessing_usagers.joblib')
df_veh = load(r'..\..\data\processed\2_preprocessing\1.3-leibold-data-preprocessing_vehicles.joblib')

print("accidents shape:", df_acc.shape)
print("locactions shape:", df_loca.shape)
print("individuals shape:", df_ind.shape)
print("vehicles shape:", df_veh.shape)

display(df_acc.head(3))
display(df_loca.head(3))
display(df_ind.head(3))
display(df_veh.head(3))

df_acc.info()
df_loca.info()
df_ind.info()
df_veh.info()
# Out:
# accidents shape: (327628, 15)
# locactions shape: (359510, 9)
# individuals shape: (733875, 15)
# vehicles shape: (559847, 8)
#         acc_num   acc_date  acc_year  acc_month  acc_hour acc_department  \
# 0  201900000001 2019-11-30      2019         11         1             93
# 1  201900000002 2019-11-30      2019         11         2             93
# 2  201900000003 2019-11-28      2019         11        15             92
#
#   acc_municipality  acc_metro  acc_long    acc_lat  acc_ambient_lightning  \
# 0            93053          1  2.470120  48.896210                    4.0
# 1            93066          1  2.368800  48.930700                    3.0
# 2            92036          1  2.319174  48.935872                    1.0
#
#    acc_atmosphere  acc_urbanization_level  acc_intersection  \
# 0             1.0                       1               1.0
# 1             1.0                       1               1.0
# 2             1.0                       1               1.0
#
#    acc_collision_type
# 0                 2.0
# 1                 6.0
# 2                 4.0
#         acc_num  loca_road_cat  loca_traffic_circul  loca_road_lanes  \
# 0  201900000001              1                    3             10.0
# 1  201900000002              1                    1              2.0
# 2  201900000003              1                    3              8.0
#
#    loca_road_gradient  loca_road_view  loca_road_surface_cond  loca_accident  \
# 0                   1             2.0                     1.0              1
# 1                   4             2.0                     1.0              1
# 2                   1             3.0                     1.0              1
#
#    loca_max_speed
# 0            70.0
# 1            70.0
# 2            90.0
#         acc_num    ind_vehID veh_num  ind_place  ind_cat  ind_severity  \
# 0  201900000001  138 306 524     B01          2        2             2
# 1  201900000001  138 306 524     B01          1        1             2
# 2  201900000001  138 306 525     A01          1        1             1
#
#    ind_sex  ind_trip  ind_secu1  ind_secu2  ind_location  ind_action  \
# 0        2         0          1          0          <NA>        <NA>
# 1        2         5          1          0          <NA>        <NA>
# 2        1         0          1          0          <NA>        <NA>
#
#    ind_year  ind_age  ind_age_group
# 0      2019       17              1
# 1      2019       26              3
# 2      2019       60              4
#         acc_num  veh_cat  veh_fixed_obstacle  veh_moving_obstacle  veh_impact  \
# 0  201900000001        7                   0                    2         5.0
# 1  201900000001       17                   1                    0         3.0
# 2  201900000002        7                   4                    0         1.0
#
#    veh_maneuver  veh_motor       veh_id
# 0          23.0          1  138 306 524
# 1          11.0          1  138 306 525
# 2           NaN          1  138 306 523
# <class 'pandas.core.frame.DataFrame'>
# Index: 327628 entries, 0 to 54401
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   acc_num                 327628 non-null  int64
#  1   acc_date                327628 non-null  datetime64[ns]
#  2   acc_year                327628 non-null  int64
#  3   acc_month               327628 non-null  int64
#  4   acc_hour                327628 non-null  int64
#  5   acc_department          327628 non-null  object
#  6   acc_municipality        327628 non-null  object
#  7   acc_metro               327628 non-null  int64
#  8   acc_long                327628 non-null  float64
#  9   acc_lat                 327628 non-null  float64
#  10  acc_ambient_lightning   327619 non-null  float64
#  11  acc_atmosphere          327602 non-null  float64
#  12  acc_urbanization_level  327628 non-null  int64
#  13  acc_intersection        327614 non-null  float64
#  14  acc_collision_type      326009 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(6), object(2)
# memory usage: 40.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 359510 entries, 0 to 359511
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   acc_num                 359510 non-null  int64
#  1   loca_road_cat           359510 non-null  int64
#  2   loca_traffic_circul     359510 non-null  int64
#  3   loca_road_lanes         348846 non-null  float64
#  4   loca_road_gradient      359510 non-null  int64
#  5   loca_road_view          359272 non-null  float64
#  6   loca_road_surface_cond  359200 non-null  float64
#  7   loca_accident           359510 non-null  int64
#  8   loca_max_speed          347911 non-null  float64
# dtypes: float64(4), int64(5)
# memory usage: 27.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 733875 entries, 0 to 744574
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   acc_num        733875 non-null  int64
#  1   ind_vehID      733875 non-null  object
#  2   veh_num        733875 non-null  object
#  3   ind_place      733875 non-null  int64
#  4   ind_cat        733875 non-null  int64
#  5   ind_severity   733875 non-null  int64
#  6   ind_sex        733875 non-null  int64
#  7   ind_trip       733875 non-null  int64
#  8   ind_secu1      732986 non-null  Int64
#  9   ind_secu2      441339 non-null  Int64
#  10  ind_location   402127 non-null  Int64
#  11  ind_action     433328 non-null  Int64
#  12  ind_year       733875 non-null  int64
#  13  ind_age        733875 non-null  Int64
#  14  ind_age_group  733875 non-null  Int64
# dtypes: Int64(6), int64(7), object(2)
# memory usage: 93.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559847 entries, 0 to 559846
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   acc_num              559847 non-null  int64
#  1   veh_cat              559847 non-null  int64
#  2   veh_fixed_obstacle   559847 non-null  int64
#  3   veh_moving_obstacle  559847 non-null  int64
#  4   veh_impact           559548 non-null  float64
#  5   veh_maneuver         524039 non-null  float64
#  6   veh_motor            559847 non-null  int64
#  7   veh_id               559847 non-null  object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 34.2+ MB

# %%
#----------------------------------------------------------------------------------------------------------------------------------
# keep only one road per acc_num in df_loca for intersections
#----------------------------------------------------------------------------------------------------------------------------------
# Step 1: compute group-level metadata
meta = (
    df_loca.groupby("acc_num")
           .agg(
               loca_road_counts=("acc_num", "size"),
               loca_max_speed_min=("loca_max_speed", "min"),
               loca_max_speed_max=("loca_max_speed", "max")
           )
           .reset_index()
)

# Step 2: add derived variables
meta["loca_is_intersection"] = (meta["loca_road_counts"] > 1).astype(int)
meta["loca_max_speed_dif"] = meta["loca_max_speed_max"] - meta["loca_max_speed_min"]

# Step 3: select representative row per acc_num
# - keep row with max loca_max_speed
# - if tie, keep first occurrence
idx = (
    df_loca.sort_values(["acc_num", "loca_max_speed"], ascending=[True, False])
           .groupby("acc_num")
           .head(1)
           .index
)

df_representative = df_loca.loc[idx].reset_index(drop=True)

# Step 4: merge metadata back
df_loca_no_intersec = df_representative.merge(
    meta[["acc_num", "loca_is_intersection", "loca_road_counts", "loca_max_speed_dif"]],
    on="acc_num", how="left"
)

# %%
#----------------------------------------------------------------------------------------------------------------------------------
# check shape of new df without intersections
#----------------------------------------------------------------------------------------------------------------------------------
print("locactions shape:", df_loca.shape)
print("loca_no_intersec shape:", df_loca_no_intersec.shape)

display(df_loca_no_intersec.head(3))

df_loca_no_intersec.info()
# Out:
# locactions shape: (359510, 9)
# loca_no_intersec shape: (327628, 12)
#         acc_num  loca_road_cat  loca_traffic_circul  loca_road_lanes  \
# 0  201900000001              1                    3             10.0
# 1  201900000002              1                    1              2.0
# 2  201900000003              1                    3              8.0
#
#    loca_road_gradient  loca_road_view  loca_road_surface_cond  loca_accident  \
# 0                   1             2.0                     1.0              1
# 1                   4             2.0                     1.0              1
# 2                   1             3.0                     1.0              1
#
#    loca_max_speed  loca_is_intersection  loca_road_counts  loca_max_speed_dif
# 0            70.0                     0                 1                 0.0
# 1            70.0                     0                 1                 0.0
# 2            90.0                     0                 1                 0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327628 entries, 0 to 327627
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   acc_num                 327628 non-null  int64
#  1   loca_road_cat           327628 non-null  int64
#  2   loca_traffic_circul     327628 non-null  int64
#  3   loca_road_lanes         322798 non-null  float64
#  4   loca_road_gradient      327628 non-null  int64
#  5   loca_road_view          327585 non-null  float64
#  6   loca_road_surface_cond  327550 non-null  float64
#  7   loca_accident           327628 non-null  int64
#  8   loca_max_speed          322482 non-null  float64
#  9   loca_is_intersection    327628 non-null  int64
#  10  loca_road_counts        327628 non-null  int64
#  11  loca_max_speed_dif      322482 non-null  float64
# dtypes: float64(5), int64(7)
# memory usage: 30.0 MB

# %%
#----------------------------------------------------------------------------------------------------------------------------------
# list all intersection accidents to check examples 
#----------------------------------------------------------------------------------------------------------------------------------
# Find acc_num values with more than one row
multi_acc_nums = df_loca["acc_num"].value_counts()
multi_acc_nums = multi_acc_nums[multi_acc_nums > 1].index

# Filter df_loca to only those rows
df_loca_multi = df_loca[df_loca["acc_num"].isin(multi_acc_nums)]

# Optional: sort for readability
df_loca_multi = df_loca_multi.sort_values(["acc_num", "loca_max_speed"]).reset_index(drop=True)

# Show result
display(df_loca_multi)
# Out:
#             acc_num  loca_road_cat  loca_traffic_circul  loca_road_lanes  \
# 0      202300000001              5                    1              2.0
# 1      202300000001              5                    1              1.0
# 2      202300000003              4                    2              4.0
# 3      202300000003              4                    2              4.0
# 4      202300000005              5                    1              1.0
# ...             ...            ...                  ...              ...
# 63392  202400054388              5                    1              2.0
# 63393  202400054393              4                    1              1.0
# 63394  202400054393              4                    2              4.0
# 63395  202400054398              4                    2              3.0
# 63396  202400054398              4                    1              1.0
#
#        loca_road_gradient  loca_road_view  loca_road_surface_cond  \
# 0                       1             1.0                     2.0
# 1                       1             1.0                     2.0
# 2                       1             1.0                     2.0
# 3                       1             1.0                     2.0
# 4                       1             1.0                     2.0
# ...                   ...             ...                     ...
# 63392                   1             1.0                     1.0
# 63393                   1             1.0                     1.0
# 63394                   1             1.0                     1.0
# 63395                   1             1.0                     2.0
# 63396                   1             1.0                     2.0
#
#        loca_accident  loca_max_speed
# 0                  1            30.0
# 1                  1            30.0
# 2                  1            50.0
# 3                  1            50.0
# 4                  1            30.0
# ...              ...             ...
# 63392              1            50.0
# 63393              7            30.0
# 63394              1            50.0
# 63395              4            50.0
# 63396              4             NaN
#
# [63397 rows x 9 columns]

# %%
#----------------------------------------------------------------------------------------------------------------------------------
# check single examples
#----------------------------------------------------------------------------------------------------------------------------------
display(df_loca.loc[df_loca['acc_num']==202400054388])
display(df_loca_no_intersec.loc[df_loca_no_intersec['acc_num']==202400054388])

display(df_loca.loc[df_loca['acc_num']==202400054393])
display(df_loca_no_intersec.loc[df_loca_no_intersec['acc_num']==202400054393])
# Out:
#              acc_num  loca_road_cat  loca_traffic_circul  loca_road_lanes  \
# 359494  202400054388              5                    1              2.0
# 359495  202400054388              5                    2              NaN
#
#         loca_road_gradient  loca_road_view  loca_road_surface_cond  \
# 359494                   1             1.0                     1.0
# 359495                   1             1.0                     1.0
#
#         loca_accident  loca_max_speed
# 359494              1            50.0
# 359495              1            30.0
#              acc_num  loca_road_cat  loca_traffic_circul  loca_road_lanes  \
# 327613  202400054388              5                    1              2.0
#
#         loca_road_gradient  loca_road_view  loca_road_surface_cond  \
# 327613                   1             1.0                     1.0
#
#         loca_accident  loca_max_speed  loca_is_intersection  loca_road_counts  \
# 327613              1            50.0                     1                 2
#
#         loca_max_speed_dif
# 327613                20.0
#              acc_num  loca_road_cat  loca_traffic_circul  loca_road_lanes  \
# 359500  202400054393              4                    2              4.0
# 359501  202400054393              4                    1              1.0
#
#         loca_road_gradient  loca_road_view  loca_road_surface_cond  \
# 359500                   1             1.0                     1.0
# 359501                   1             1.0                     1.0
#
#         loca_accident  loca_max_speed
# 359500              1            50.0
# 359501              7            30.0
#              acc_num  loca_road_cat  loca_traffic_circul  loca_road_lanes  \
# 327618  202400054393              4                    2              4.0
#
#         loca_road_gradient  loca_road_view  loca_road_surface_cond  \
# 327618                   1             1.0                     1.0
#
#         loca_accident  loca_max_speed  loca_is_intersection  loca_road_counts  \
# 327618              1            50.0                     1                 2
#
#         loca_max_speed_dif
# 327618                20.0

# %%
#---------------------------------------------------------------------------------------------------------------------------------------
# check missing values
#---------------------------------------------------------------------------------------------------------------------------------------
print("\nMissing values in df_loca:")
print(df_loca.isna().sum()[df_loca.isna().sum() > 0], end="\n")

print("\nMissing values in df_loca_no_intersec:")
print(df_loca_no_intersec.isna().sum()[df_loca_no_intersec.isna().sum() > 0])
# Out:
# Missing values in df_loca:
# loca_road_lanes           10664
# loca_road_view              238
# loca_road_surface_cond      310
# loca_max_speed            11599
# dtype: int64
#
# Missing values in df_loca_no_intersec:
# loca_road_lanes           4830
# loca_road_view              43
# loca_road_surface_cond      78
# loca_max_speed            5146
# loca_max_speed_dif        5146
# dtype: int64

# %%
#---------------------------------------------------------------------------------------------------------------------------------------
# concat ind, acc, veh, loca: starting with ind dataset
#---------------------------------------------------------------------------------------------------------------------------------------
# not merged in order of documentation from Frensh government to avoid additional lines.
# if f.e. two vehicles are involved in accident but only one person is known and has data we only want to keep the lines where we have info of our target variable

print("IND shape:", df_ind.shape)

df = pd.merge(df_ind, df_acc, on = 'acc_num', how='left')
print("IND + ACC shape:", df.shape)

df = pd.merge(df, df_veh, left_on = ['acc_num', 'ind_vehID'], right_on = ['acc_num', 'veh_id'], how='left')
print("IND + ACC + VEH shape:", df.shape)

df = pd.merge(df, df_loca_no_intersec, on = 'acc_num', how='left').reset_index(drop=True)
print("IND + ACC + VEH + LOCA shape:", df.shape)
# Out:
# IND shape: (733875, 15)
# IND + ACC shape: (733875, 29)
# IND + ACC + VEH shape: (733875, 36)
# IND + ACC + VEH + LOCA shape: (733875, 47)

# %%
#---------------------------------------------------------------------------------------------------------------------------------------
# remove rows with accidents outside France mainland
#---------------------------------------------------------------------------------------------------------------------------------------
#df['acc_metro'].value_counts()
print("df shape BEFORE removing accidents out of France mainland:", df.shape)
df = df.loc[df['acc_metro']==1]
print("df shape AFTER removing accidents out of France mainland:", df.shape)
# Out:
# df shape BEFORE removing accidents out of France mainland: (733875, 47)
# df shape AFTER removing accidents out of France mainland: (692159, 47)

# %%
#---------------------------------------------------------------------------------------------------------------------------------------
# remove irrelvant columns (if not already removed in prior joblib files)
#---------------------------------------------------------------------------------------------------------------------------------------
cols_remove = ['veh_num', 'ind_vehID']

df = df.drop(columns=cols_remove, errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 692159 entries, 0 to 733874
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   acc_num                 692159 non-null  int64
#  1   ind_place               692159 non-null  int64
#  2   ind_cat                 692159 non-null  int64
#  3   ind_severity            692159 non-null  int64
#  4   ind_sex                 692159 non-null  int64
#  5   ind_trip                692159 non-null  int64
#  6   ind_secu1               691305 non-null  Int64
#  7   ind_secu2               415207 non-null  Int64
#  8   ind_location            379506 non-null  Int64
#  9   ind_action              409030 non-null  Int64
#  10  ind_year                692159 non-null  int64
#  11  ind_age                 692159 non-null  Int64
#  12  ind_age_group           692159 non-null  Int64
#  13  acc_date                692159 non-null  datetime64[ns]
#  14  acc_year                692159 non-null  int64
#  15  acc_month               692159 non-null  int64
#  16  acc_hour                692159 non-null  int64
#  17  acc_department          692159 non-null  object
#  18  acc_municipality        692159 non-null  object
#  19  acc_metro               692159 non-null  int64
#  20  acc_long                692159 non-null  float64
#  21  acc_lat                 692159 non-null  float64
#  22  acc_ambient_lightning   692149 non-null  float64
#  23  acc_atmosphere          692122 non-null  float64
#  24  acc_urbanization_level  692159 non-null  int64
#  25  acc_intersection        692131 non-null  float64
#  26  acc_collision_type      688397 non-null  float64
#  27  veh_cat                 692159 non-null  int64
#  28  veh_fixed_obstacle      692159 non-null  int64
#  29  veh_moving_obstacle     692159 non-null  int64
#  30  veh_impact              691880 non-null  float64
#  31  veh_maneuver            652420 non-null  float64
#  32  veh_motor               692159 non-null  int64
#  33  veh_id                  692159 non-null  object
#  34  loca_road_cat           692159 non-null  int64
#  35  loca_traffic_circul     692159 non-null  int64
#  36  loca_road_lanes         682328 non-null  float64
#  37  loca_road_gradient      692159 non-null  int64
#  38  loca_road_view          692102 non-null  float64
#  39  loca_road_surface_cond  692041 non-null  float64
#  40  loca_accident           692159 non-null  int64
#  41  loca_max_speed          682509 non-null  float64
#  42  loca_is_intersection    692159 non-null  int64
#  43  loca_road_counts        692159 non-null  int64
#  44  loca_max_speed_dif      682509 non-null  float64
# dtypes: Int64(6), datetime64[ns](1), float64(13), int64(22), object(3)
# memory usage: 246.9+ MB

# %%
# -------------------------------------------------------------------------------------------------
# export final dataframe to joblib in local folder
# -------------------------------------------------------------------------------------------------
from joblib import dump

dump(df, ('C:/Users/Christian/Documents/1.0-leibold-data-preprocessing_aggr.joblib'))
# Out:
# ['C:/Users/Christian/Documents/1.0-leibold-data-preprocessing_aggr.joblib']

# %%
# ---------------------------------------------------------------------------------------
# check correlation between variables
# ---------------------------------------------------------------------------------------
# List of categorical variables
cols_cat = ['acc_year','acc_month','acc_hour','acc_ambient_lightning','acc_urbanization_level','acc_intersection','acc_atmosphere','acc_collision_type',
            'ind_place','ind_cat','ind_sex','ind_trip','ind_location','ind_action','ind_secu1','ind_secu2','ind_age_group', 
            'loca_road_cat','loca_traffic_circul','loca_road_gradient','loca_road_view','loca_road_surface_cond','loca_accident', 'loca_is_intersection',
            'veh_cat','veh_fixed_obstacle','veh_moving_obstacle','veh_impact','veh_maneuver', 'veh_motor'
           ]

cat_vars = cols_cat

# Define Cramér's V function
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x.dropna(), y.dropna())
    chi2 = stats.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    return np.sqrt(phi2 / min(k - 1, r - 1))

    
# Compute Cramér's V for all unique pairs
results = []
for var1, var2 in itertools.combinations(cat_vars, 2):
    v = cramers_v(df[var1].dropna(), df[var2].dropna())
    results.append({
        'Variable 1': var1,
        'Variable 2': var2,
        'Cramér\'s V': round(v, 4)
    })

# Convert to DataFrame
cramers_df = pd.DataFrame(results)

pd.set_option('display.max_rows', None)  # Show all rows
display(cramers_df.sort_values(by="Cramér's V", ascending=False))
pd.reset_option('display.max_rows')
# Out:
#                  Variable 1              Variable 2  Cramér's V
# 204               ind_place                 ind_cat      0.9969
# 228                 ind_cat              ind_action      0.6925
# 227                 ind_cat            ind_location      0.6921
# 122  acc_urbanization_level           loca_road_cat      0.6517
# 229                 ind_cat               ind_secu1      0.5525
# 424                 veh_cat               veh_motor      0.5106
# 152        acc_intersection    loca_is_intersection      0.4852
# 241                 ind_cat     veh_moving_obstacle      0.4846
# 22                 acc_year    loca_is_intersection      0.4733
# 57                 acc_hour   acc_ambient_lightning      0.4270
# 282            ind_location              ind_action      0.4118
# 324               ind_secu1                 veh_cat      0.3997
# 315               ind_secu1               ind_secu2      0.3951
# 173          acc_atmosphere  loca_road_surface_cond      0.3906
# 84    acc_ambient_lightning  acc_urbanization_level      0.3871
# 200      acc_collision_type     veh_moving_obstacle      0.3745
# 117  acc_urbanization_level            ind_location      0.3441
# 357           loca_road_cat     loca_traffic_circul      0.3334
# 209               ind_place               ind_secu1      0.3319
# 183      acc_collision_type                 ind_cat      0.3313
# 208               ind_place              ind_action      0.3265
# 207               ind_place            ind_location      0.3263
# 295            ind_location     veh_moving_obstacle      0.3188
# 118  acc_urbanization_level              ind_action      0.3183
# 311              ind_action     veh_moving_obstacle      0.3152
# 283            ind_location               ind_secu1      0.3119
# 299              ind_action               ind_secu1      0.3103
# 131  acc_urbanization_level     veh_moving_obstacle      0.3066
# 110  acc_urbanization_level        acc_intersection      0.3056
# 112  acc_urbanization_level      acc_collision_type      0.3041
# 201      acc_collision_type              veh_impact      0.2950
# 338               ind_secu2                 veh_cat      0.2942
# 130  acc_urbanization_level      veh_fixed_obstacle      0.2875
# 221               ind_place     veh_moving_obstacle      0.2807
# 231                 ind_cat           ind_age_group      0.2797
# 202      acc_collision_type            veh_maneuver      0.2698
# 133  acc_urbanization_level            veh_maneuver      0.2671
# 129  acc_urbanization_level                 veh_cat      0.2599
# 425      veh_fixed_obstacle     veh_moving_obstacle      0.2560
# 123  acc_urbanization_level     loca_traffic_circul      0.2490
# 127  acc_urbanization_level           loca_accident      0.2474
# 409           loca_accident      veh_fixed_obstacle      0.2432
# 113  acc_urbanization_level               ind_place      0.2408
# 211               ind_place           ind_age_group      0.2293
# 114  acc_urbanization_level                 ind_cat      0.2249
# 186      acc_collision_type            ind_location      0.2220
# 187      acc_collision_type              ind_action      0.2180
# 119  acc_urbanization_level               ind_secu1      0.2150
# 326               ind_secu1     veh_moving_obstacle      0.2096
# 276                ind_trip                 veh_cat      0.2067
# 410           loca_accident     veh_moving_obstacle      0.2019
# 268                ind_trip           ind_age_group      0.1991
# 153        acc_intersection                 veh_cat      0.1982
# 210               ind_place               ind_secu2      0.1944
# 412           loca_accident            veh_maneuver      0.1935
# 182      acc_collision_type               ind_place      0.1928
# 197      acc_collision_type    loca_is_intersection      0.1917
# 432              veh_impact            veh_maneuver      0.1906
# 226                 ind_cat                ind_trip      0.1884
# 125  acc_urbanization_level          loca_road_view      0.1854
# 199      acc_collision_type      veh_fixed_obstacle      0.1829
# 188      acc_collision_type               ind_secu1      0.1824
# 120  acc_urbanization_level               ind_secu2      0.1766
# 155        acc_intersection     veh_moving_obstacle      0.1744
# 191      acc_collision_type           loca_road_cat      0.1741
# 258                 ind_sex                 veh_cat      0.1732
# 418    loca_is_intersection            veh_maneuver      0.1720
# 196      acc_collision_type           loca_accident      0.1691
# 239                 ind_cat                 veh_cat      0.1689
# 134  acc_urbanization_level               veh_motor      0.1688
# 136        acc_intersection      acc_collision_type      0.1686
# 378     loca_traffic_circul            veh_maneuver      0.1673
# 316               ind_secu1           ind_age_group      0.1664
# 367           loca_road_cat            veh_maneuver      0.1653
# 192      acc_collision_type     loca_traffic_circul      0.1648
# 157        acc_intersection            veh_maneuver      0.1613
# 205               ind_place                 ind_sex      0.1610
# 225                 ind_cat                 ind_sex      0.1608
# 408           loca_accident                 veh_cat      0.1578
# 291            ind_location           loca_accident      0.1551
# 116  acc_urbanization_level                ind_trip      0.1539
# 351           ind_age_group                 veh_cat      0.1538
# 430     veh_moving_obstacle            veh_maneuver      0.1520
# 30                acc_month   acc_ambient_lightning      0.1482
# 362           loca_road_cat    loca_is_intersection      0.1479
# 97    acc_ambient_lightning           loca_road_cat      0.1467
# 329               ind_secu1               veh_motor      0.1448
# 232                 ind_cat           loca_road_cat      0.1432
# 380      loca_road_gradient          loca_road_view      0.1424
# 328               ind_secu1            veh_maneuver      0.1409
# 243                 ind_cat            veh_maneuver      0.1404
# 382      loca_road_gradient           loca_accident      0.1375
# 132  acc_urbanization_level              veh_impact      0.1369
# 297            ind_location            veh_maneuver      0.1358
# 65                 acc_hour                ind_trip      0.1355
# 194      acc_collision_type          loca_road_view      0.1343
# 149        acc_intersection          loca_road_view      0.1339
# 70                 acc_hour           ind_age_group      0.1337
# 429     veh_moving_obstacle              veh_impact      0.1336
# 248                 ind_sex               ind_secu1      0.1335
# 286            ind_location           loca_road_cat      0.1330
# 301              ind_action           ind_age_group      0.1321
# 128  acc_urbanization_level    loca_is_intersection      0.1318
# 230                 ind_cat               ind_secu2      0.1310
# 146        acc_intersection           loca_road_cat      0.1282
# 245                 ind_sex                ind_trip      0.1245
# 394          loca_road_view      veh_fixed_obstacle      0.1239
# 364           loca_road_cat      veh_fixed_obstacle      0.1215
# 342               ind_secu2            veh_maneuver      0.1203
# 105   acc_ambient_lightning      veh_fixed_obstacle      0.1195
# 397          loca_road_view            veh_maneuver      0.1187
# 395          loca_road_view     veh_moving_obstacle      0.1181
# 285            ind_location           ind_age_group      0.1166
# 240                 ind_cat      veh_fixed_obstacle      0.1160
# 361           loca_road_cat           loca_accident      0.1158
# 198      acc_collision_type                 veh_cat      0.1158
# 413           loca_accident               veh_motor      0.1147
# 124  acc_urbanization_level      loca_road_gradient      0.1130
# 365           loca_road_cat     veh_moving_obstacle      0.1125
# 375     loca_traffic_circul      veh_fixed_obstacle      0.1117
# 246                 ind_sex            ind_location      0.1117
# 363           loca_road_cat                 veh_cat      0.1106
# 302              ind_action           loca_road_cat      0.1103
# 147        acc_intersection     loca_traffic_circul      0.1103
# 327               ind_secu1              veh_impact      0.1085
# 63                 acc_hour                 ind_cat      0.1065
# 219               ind_place                 veh_cat      0.1064
# 284            ind_location               ind_secu2      0.1055
# 391          loca_road_view           loca_accident      0.1051
# 247                 ind_sex              ind_action      0.1050
# 48                acc_month  loca_road_surface_cond      0.1048
# 206               ind_place                ind_trip      0.1046
# 377     loca_traffic_circul              veh_impact      0.1036
# 86    acc_ambient_lightning          acc_atmosphere      0.1033
# 422                 veh_cat              veh_impact      0.1030
# 249                 ind_sex               ind_secu2      0.1020
# 419    loca_is_intersection               veh_motor      0.1014
# 151        acc_intersection           loca_accident      0.1003
# 317               ind_secu1           loca_road_cat      0.0977
# 33                acc_month          acc_atmosphere      0.0975
# 287            ind_location     loca_traffic_circul      0.0965
# 85    acc_ambient_lightning        acc_intersection      0.0957
# 353           ind_age_group     veh_moving_obstacle      0.0954
# 330               ind_secu2           ind_age_group      0.0947
# 101   acc_ambient_lightning  loca_road_surface_cond      0.0945
# 313              ind_action            veh_maneuver      0.0942
# 244                 ind_cat               veh_motor      0.0940
# 106   acc_ambient_lightning     veh_moving_obstacle      0.0933
# 237                 ind_cat           loca_accident      0.0928
# 80                 acc_hour     veh_moving_obstacle      0.0923
# 242                 ind_cat              veh_impact      0.0919
# 359           loca_road_cat          loca_road_view      0.0915
# 102   acc_ambient_lightning           loca_accident      0.0915
# 264                ind_trip            ind_location      0.0904
# 189      acc_collision_type               ind_secu2      0.0902
# 96    acc_ambient_lightning           ind_age_group      0.0902
# 423                 veh_cat            veh_maneuver      0.0896
# 372     loca_traffic_circul           loca_accident      0.0895
# 366           loca_road_cat              veh_impact      0.0893
# 307              ind_action           loca_accident      0.0890
# 265                ind_trip              ind_action      0.0890
# 416    loca_is_intersection     veh_moving_obstacle      0.0881
# 266                ind_trip               ind_secu1      0.0868
# 331               ind_secu2           loca_road_cat      0.0860
# 300              ind_action               ind_secu2      0.0849
# 104   acc_ambient_lightning                 veh_cat      0.0847
# 414    loca_is_intersection                 veh_cat      0.0843
# 103   acc_ambient_lightning    loca_is_intersection      0.0841
# 434            veh_maneuver               veh_motor      0.0839
# 373     loca_traffic_circul    loca_is_intersection      0.0833
# 87    acc_ambient_lightning      acc_collision_type      0.0832
# 415    loca_is_intersection      veh_fixed_obstacle      0.0831
# 212               ind_place           loca_road_cat      0.0823
# 28                 acc_year               veh_motor      0.0817
# 417    loca_is_intersection              veh_impact      0.0816
# 374     loca_traffic_circul                 veh_cat      0.0815
# 278                ind_trip     veh_moving_obstacle      0.0805
# 368           loca_road_cat               veh_motor      0.0787
# 89    acc_ambient_lightning                 ind_cat      0.0781
# 91    acc_ambient_lightning                ind_trip      0.0778
# 355           ind_age_group            veh_maneuver      0.0778
# 407           loca_accident    loca_is_intersection      0.0775
# 427      veh_fixed_obstacle            veh_maneuver      0.0774
# 111  acc_urbanization_level          acc_atmosphere      0.0771
# 269                ind_trip           loca_road_cat      0.0769
# 58                 acc_hour  acc_urbanization_level      0.0762
# 341               ind_secu2              veh_impact      0.0761
# 292            ind_location    loca_is_intersection      0.0760
# 92    acc_ambient_lightning            ind_location      0.0759
# 289            ind_location          loca_road_view      0.0755
# 332               ind_secu2     loca_traffic_circul      0.0753
# 267                ind_trip               ind_secu2      0.0748
# 126  acc_urbanization_level  loca_road_surface_cond      0.0733
# 411           loca_accident              veh_impact      0.0729
# 340               ind_secu2     veh_moving_obstacle      0.0729
# 190      acc_collision_type           ind_age_group      0.0724
# 303              ind_action     loca_traffic_circul      0.0723
# 108   acc_ambient_lightning            veh_maneuver      0.0719
# 421                 veh_cat     veh_moving_obstacle      0.0718
# 426      veh_fixed_obstacle              veh_impact      0.0716
# 396          loca_road_view              veh_impact      0.0710
# 305              ind_action          loca_road_view      0.0695
# 223               ind_place            veh_maneuver      0.0689
# 185      acc_collision_type                ind_trip      0.0687
# 433              veh_impact               veh_motor      0.0678
# 154        acc_intersection      veh_fixed_obstacle      0.0673
# 334               ind_secu2          loca_road_view      0.0663
# 280                ind_trip            veh_maneuver      0.0661
# 343               ind_secu2               veh_motor      0.0655
# 294            ind_location      veh_fixed_obstacle      0.0652
# 392          loca_road_view    loca_is_intersection      0.0649
# 88    acc_ambient_lightning               ind_place      0.0648
# 293            ind_location                 veh_cat      0.0647
# 322               ind_secu1           loca_accident      0.0643
# 98    acc_ambient_lightning     loca_traffic_circul      0.0632
# 156        acc_intersection              veh_impact      0.0627
# 158        acc_intersection               veh_motor      0.0626
# 318               ind_secu1     loca_traffic_circul      0.0624
# 352           ind_age_group      veh_fixed_obstacle      0.0619
# 262                 ind_sex            veh_maneuver      0.0618
# 93    acc_ambient_lightning              ind_action      0.0617
# 270                ind_trip     loca_traffic_circul      0.0610
# 235                 ind_cat          loca_road_view      0.0604
# 220               ind_place      veh_fixed_obstacle      0.0603
# 233                 ind_cat     loca_traffic_circul      0.0595
# 61                 acc_hour      acc_collision_type      0.0592
# 272                ind_trip          loca_road_view      0.0590
# 141        acc_intersection            ind_location      0.0584
# 79                 acc_hour      veh_fixed_obstacle      0.0581
# 193      acc_collision_type      loca_road_gradient      0.0578
# 310              ind_action      veh_fixed_obstacle      0.0578
# 277                ind_trip      veh_fixed_obstacle      0.0577
# 296            ind_location              veh_impact      0.0568
# 217               ind_place           loca_accident      0.0568
# 274                ind_trip           loca_accident      0.0567
# 64                 acc_hour                 ind_sex      0.0563
# 281                ind_trip               veh_motor      0.0561
# 390          loca_road_view  loca_road_surface_cond      0.0555
# 376     loca_traffic_circul     veh_moving_obstacle      0.0553
# 224               ind_place               veh_motor      0.0552
# 0                  acc_year               acc_month      0.0549
# 60                 acc_hour          acc_atmosphere      0.0548
# 354           ind_age_group              veh_impact      0.0548
# 309              ind_action                 veh_cat      0.0548
# 100   acc_ambient_lightning          loca_road_view      0.0545
# 312              ind_action              veh_impact      0.0545
# 76                 acc_hour           loca_accident      0.0545
# 203      acc_collision_type               veh_motor      0.0541
# 370     loca_traffic_circul          loca_road_view      0.0534
# 393          loca_road_view                 veh_cat      0.0533
# 94    acc_ambient_lightning               ind_secu1      0.0533
# 250                 ind_sex           ind_age_group      0.0531
# 260                 ind_sex     veh_moving_obstacle      0.0531
# 336               ind_secu2           loca_accident      0.0530
# 36                acc_month                 ind_cat      0.0530
# 215               ind_place          loca_road_view      0.0529
# 31                acc_month  acc_urbanization_level      0.0527
# 62                 acc_hour               ind_place      0.0526
# 195      acc_collision_type  loca_road_surface_cond      0.0524
# 379     loca_traffic_circul               veh_motor      0.0524
# 339               ind_secu2      veh_fixed_obstacle      0.0522
# 298            ind_location               veh_motor      0.0513
# 358           loca_road_cat      loca_road_gradient      0.0509
# 107   acc_ambient_lightning              veh_impact      0.0507
# 344           ind_age_group           loca_road_cat      0.0503
# 308              ind_action    loca_is_intersection      0.0503
# 213               ind_place     loca_traffic_circul      0.0498
# 386      loca_road_gradient     veh_moving_obstacle      0.0480
# 325               ind_secu1      veh_fixed_obstacle      0.0478
# 38                acc_month                ind_trip      0.0466
# 385      loca_road_gradient      veh_fixed_obstacle      0.0466
# 222               ind_place              veh_impact      0.0464
# 401  loca_road_surface_cond                 veh_cat      0.0461
# 345           ind_age_group     loca_traffic_circul      0.0458
# 314              ind_action               veh_motor      0.0456
# 279                ind_trip              veh_impact      0.0456
# 109   acc_ambient_lightning               veh_motor      0.0455
# 388      loca_road_gradient            veh_maneuver      0.0455
# 261                 ind_sex              veh_impact      0.0445
# 349           ind_age_group           loca_accident      0.0445
# 148        acc_intersection      loca_road_gradient      0.0441
# 138        acc_intersection                 ind_cat      0.0437
# 72                 acc_hour     loca_traffic_circul      0.0433
# 369     loca_traffic_circul      loca_road_gradient      0.0427
# 403  loca_road_surface_cond     veh_moving_obstacle      0.0427
# 140        acc_intersection                ind_trip      0.0426
# 288            ind_location      loca_road_gradient      0.0423
# 75                 acc_hour  loca_road_surface_cond      0.0422
# 420                 veh_cat      veh_fixed_obstacle      0.0421
# 428      veh_fixed_obstacle               veh_motor      0.0417
# 143        acc_intersection               ind_secu1      0.0408
# 184      acc_collision_type                 ind_sex      0.0407
# 66                 acc_hour            ind_location      0.0403
# 71                 acc_hour           loca_road_cat      0.0399
# 356           ind_age_group               veh_motor      0.0398
# 14                 acc_year               ind_secu2      0.0398
# 23                 acc_year                 veh_cat      0.0398
# 360           loca_road_cat  loca_road_surface_cond      0.0386
# 304              ind_action      loca_road_gradient      0.0380
# 68                 acc_hour               ind_secu1      0.0377
# 78                 acc_hour                 veh_cat      0.0375
# 402  loca_road_surface_cond      veh_fixed_obstacle      0.0375
# 95    acc_ambient_lightning               ind_secu2      0.0374
# 90    acc_ambient_lightning                 ind_sex      0.0373
# 53                acc_month     veh_moving_obstacle      0.0366
# 74                 acc_hour          loca_road_view      0.0365
# 21                 acc_year           loca_accident      0.0365
# 176          acc_atmosphere                 veh_cat      0.0365
# 144        acc_intersection               ind_secu2      0.0364
# 333               ind_secu2      loca_road_gradient      0.0363
# 337               ind_secu2    loca_is_intersection      0.0360
# 159          acc_atmosphere      acc_collision_type      0.0360
# 16                 acc_year           loca_road_cat      0.0358
# 271                ind_trip      loca_road_gradient      0.0354
# 381      loca_road_gradient  loca_road_surface_cond      0.0352
# 161          acc_atmosphere                 ind_cat      0.0352
# 178          acc_atmosphere     veh_moving_obstacle      0.0348
# 399  loca_road_surface_cond           loca_accident      0.0348
# 323               ind_secu1    loca_is_intersection      0.0347
# 383      loca_road_gradient    loca_is_intersection      0.0342
# 169          acc_atmosphere           loca_road_cat      0.0339
# 431     veh_moving_obstacle               veh_motor      0.0339
# 67                 acc_hour              ind_action      0.0338
# 234                 ind_cat      loca_road_gradient      0.0335
# 170          acc_atmosphere     loca_traffic_circul      0.0333
# 82                 acc_hour            veh_maneuver      0.0331
# 321               ind_secu1  loca_road_surface_cond      0.0330
# 166          acc_atmosphere               ind_secu1      0.0329
# 275                ind_trip    loca_is_intersection      0.0327
# 177          acc_atmosphere      veh_fixed_obstacle      0.0327
# 172          acc_atmosphere          loca_road_view      0.0325
# 13                 acc_year               ind_secu1      0.0323
# 39                acc_month            ind_location      0.0323
# 81                 acc_hour              veh_impact      0.0317
# 335               ind_secu2  loca_road_surface_cond      0.0311
# 12                 acc_year              ind_action      0.0310
# 29                acc_month                acc_hour      0.0309
# 384      loca_road_gradient                 veh_cat      0.0304
# 41                acc_month               ind_secu1      0.0299
# 34                acc_month      acc_collision_type      0.0298
# 168          acc_atmosphere           ind_age_group      0.0298
# 83                 acc_hour               veh_motor      0.0293
# 5                  acc_year          acc_atmosphere      0.0292
# 398          loca_road_view               veh_motor      0.0291
# 142        acc_intersection              ind_action      0.0286
# 51                acc_month                 veh_cat      0.0286
# 50                acc_month    loca_is_intersection      0.0280
# 69                 acc_hour               ind_secu2      0.0280
# 371     loca_traffic_circul  loca_road_surface_cond      0.0274
# 42                acc_month               ind_secu2      0.0274
# 174          acc_atmosphere           loca_accident      0.0270
# 180          acc_atmosphere            veh_maneuver      0.0269
# 163          acc_atmosphere                ind_trip      0.0269
# 214               ind_place      loca_road_gradient      0.0265
# 35                acc_month               ind_place      0.0265
# 40                acc_month              ind_action      0.0263
# 59                 acc_hour        acc_intersection      0.0259
# 121  acc_urbanization_level           ind_age_group      0.0255
# 164          acc_atmosphere            ind_location      0.0254
# 171          acc_atmosphere      loca_road_gradient      0.0253
# 320               ind_secu1          loca_road_view      0.0252
# 347           ind_age_group          loca_road_view      0.0252
# 400  loca_road_surface_cond    loca_is_intersection      0.0250
# 387      loca_road_gradient              veh_impact      0.0250
# 236                 ind_cat  loca_road_surface_cond      0.0249
# 137        acc_intersection               ind_place      0.0248
# 405  loca_road_surface_cond            veh_maneuver      0.0246
# 99    acc_ambient_lightning      loca_road_gradient      0.0245
# 167          acc_atmosphere               ind_secu2      0.0245
# 77                 acc_hour    loca_is_intersection      0.0244
# 20                 acc_year  loca_road_surface_cond      0.0242
# 273                ind_trip  loca_road_surface_cond      0.0239
# 10                 acc_year                ind_trip      0.0234
# 175          acc_atmosphere    loca_is_intersection      0.0225
# 404  loca_road_surface_cond              veh_impact      0.0224
# 160          acc_atmosphere               ind_place      0.0221
# 25                 acc_year     veh_moving_obstacle      0.0220
# 145        acc_intersection           ind_age_group      0.0218
# 47                acc_month          loca_road_view      0.0218
# 3                  acc_year  acc_urbanization_level      0.0208
# 259                 ind_sex      veh_fixed_obstacle      0.0205
# 165          acc_atmosphere              ind_action      0.0203
# 27                 acc_year            veh_maneuver      0.0201
# 263                 ind_sex               veh_motor      0.0201
# 11                 acc_year            ind_location      0.0200
# 44                acc_month           loca_road_cat      0.0199
# 218               ind_place    loca_is_intersection      0.0199
# 150        acc_intersection  loca_road_surface_cond      0.0195
# 2                  acc_year   acc_ambient_lightning      0.0195
# 1                  acc_year                acc_hour      0.0193
# 181          acc_atmosphere               veh_motor      0.0188
# 4                  acc_year        acc_intersection      0.0187
# 135        acc_intersection          acc_atmosphere      0.0184
# 251                 ind_sex           loca_road_cat      0.0184
# 319               ind_secu1      loca_road_gradient      0.0183
# 179          acc_atmosphere              veh_impact      0.0182
# 290            ind_location  loca_road_surface_cond      0.0181
# 162          acc_atmosphere                 ind_sex      0.0181
# 348           ind_age_group  loca_road_surface_cond      0.0180
# 406  loca_road_surface_cond               veh_motor      0.0179
# 389      loca_road_gradient               veh_motor      0.0176
# 6                  acc_year      acc_collision_type      0.0174
# 49                acc_month           loca_accident      0.0168
# 55                acc_month            veh_maneuver      0.0163
# 56                acc_month               veh_motor      0.0162
# 216               ind_place  loca_road_surface_cond      0.0161
# 17                 acc_year     loca_traffic_circul      0.0155
# 238                 ind_cat    loca_is_intersection      0.0154
# 43                acc_month           ind_age_group      0.0150
# 306              ind_action  loca_road_surface_cond      0.0148
# 73                 acc_hour      loca_road_gradient      0.0143
# 45                acc_month     loca_traffic_circul      0.0139
# 255                 ind_sex  loca_road_surface_cond      0.0138
# 52                acc_month      veh_fixed_obstacle      0.0137
# 15                 acc_year           ind_age_group      0.0129
# 54                acc_month              veh_impact      0.0122
# 37                acc_month                 ind_sex      0.0121
# 256                 ind_sex           loca_accident      0.0119
# 24                 acc_year      veh_fixed_obstacle      0.0112
# 32                acc_month        acc_intersection      0.0111
# 46                acc_month      loca_road_gradient      0.0109
# 139        acc_intersection                 ind_sex      0.0106
# 8                  acc_year                 ind_cat      0.0106
# 346           ind_age_group      loca_road_gradient      0.0098
# 7                  acc_year               ind_place      0.0095
# 26                 acc_year              veh_impact      0.0081
# 257                 ind_sex    loca_is_intersection      0.0078
# 18                 acc_year      loca_road_gradient      0.0076
# 252                 ind_sex     loca_traffic_circul      0.0068
# 115  acc_urbanization_level                 ind_sex      0.0063
# 350           ind_age_group    loca_is_intersection      0.0063
# 19                 acc_year          loca_road_view      0.0057
# 9                  acc_year                 ind_sex      0.0055
# 254                 ind_sex          loca_road_view      0.0051
# 253                 ind_sex      loca_road_gradient      0.0022
